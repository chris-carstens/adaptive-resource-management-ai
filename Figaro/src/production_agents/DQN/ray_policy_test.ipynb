# %%
import requests
import numpy as np
import json

# %%
from production_agent_DQN import ProductionAgentDQN
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 from production_agent_DQN import ProductionAgentDQN
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/Figaro/src/production_agents/DQN/production_agent_DQN.py:1
# ----> 1 from ray.rllib.policy import Policy
#       2 from ray.rllib.policy.sample_batch import SampleBatch
#       3 from ray.rllib.utils.replay_buffers.replay_buffer import ReplayBuffer
#
# ModuleNotFoundError: No module named 'ray'

# %%
def random_obs():
    return {
       "n_instances": int(np.random.randint(1, 20)),
       "pressure": float(np.random.uniform(0.1, 1.0)),
       "queue_length_dominant": float(np.random.uniform(0.0, 1.0)),
       "utilization": float(np.random.uniform(0.0, 1.0)),
       "workload": float(np.random.randint(5, 20))
    }

def flatten_obs(obs_dict):
    return np.concatenate([v for v in obs_dict.values()])

learn_dict = {
    "observations": [],
    "actions": [],
    "rewards": [],
    "next_observations": [],
    "timesteps": []
}

# %%
def random_obs():
    return {
       "n_instances": int(np.random.randint(1, 7)),
       "pressure": float(np.random.uniform(0.1, 2.5)),
       "queue_length_dominant": float(np.random.uniform(0.1, 1.0)),
       "utilization": float(np.random.uniform(0.0, 1.0)),
       "workload": float(np.random.uniform(0, 1))}

# Notice that random_obs produces values without any logic (i.e. in theory if we have high utilization, that we would expect high values for pressure/queue_length_dominant/workload as well) but at least we are able to visualize that the agent works!

# %%
for i in range(100):

    print(f"\n{'=' * 15} Observation #{i+1} {'=' * 15}")
    
    observation = random_obs()
    
    # Pretty-print the observation dictionary
    print("Observation:")
    print(json.dumps(observation, indent = 4))
    
    try:
        
        response = requests.post('http://localhost:5100/action', json={'observation': observation})
        print("Response:")
        print(json.dumps(response.json(), indent = 4))

    except Exception as e:
        print("Request failed:", str(e))
# Out:
# =============== Observation #1 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.7170984915870238,
#     "queue_length_dominant": 0.4681784801426182,
#     "utilization": 0.7401638310819052,
#     "workload": 0.46637275846856996
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #2 ===============
# Observation:
# {
#     "n_instances": 3,
#     "pressure": 1.1389183270969374,
#     "queue_length_dominant": 0.4268993391975753,
#     "utilization": 0.5390113312970152,
#     "workload": 0.6391302451650778
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #3 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 1.5438806215164627,
#     "queue_length_dominant": 0.9631619304177605,
#     "utilization": 0.458556687333452,
#     "workload": 0.5718248727641303
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #4 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 0.43542032669874187,
#     "queue_length_dominant": 0.8841563798116385,
#     "utilization": 0.23562339505109187,
#     "workload": 0.7915431955891825
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #5 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 0.8653346303538115,
#     "queue_length_dominant": 0.8869886856747771,
#     "utilization": 0.8452932106945504,
#     "workload": 0.020517887001424873
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #6 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 1.2811654102809886,
#     "queue_length_dominant": 0.8719224082011323,
#     "utilization": 0.3863548271527891,
#     "workload": 0.49763205369572716
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #7 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 0.6609419290655696,
#     "queue_length_dominant": 0.8758415527012599,
#     "utilization": 0.9735246884902741,
#     "workload": 0.26270006975844784
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #8 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 0.3131673700045088,
#     "queue_length_dominant": 0.5262187961077702,
#     "utilization": 0.35010226963740687,
#     "workload": 0.7830199984675319
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #9 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 2.1466172333849376,
#     "queue_length_dominant": 0.9133866898120125,
#     "utilization": 0.3159783524369014,
#     "workload": 0.5706066493507614
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #10 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.0812119572084267,
#     "queue_length_dominant": 0.8654582915726657,
#     "utilization": 0.47788599352153915,
#     "workload": 0.06571671884809704
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #11 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.760871932017897,
#     "queue_length_dominant": 0.7114287577983298,
#     "utilization": 0.08917757881071398,
#     "workload": 0.2025320760402478
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #12 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 0.431033748245082,
#     "queue_length_dominant": 0.23507455328712223,
#     "utilization": 0.21387367828136805,
#     "workload": 0.2926480722370216
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #13 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 0.5955209337452169,
#     "queue_length_dominant": 0.3529638271909553,
#     "utilization": 0.7132268449249526,
#     "workload": 0.018025966258179538
# }
# Response:
# {
#     "action": 2
# }
#
# =============== Observation #14 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 0.4735800694244987,
#     "queue_length_dominant": 0.6276651558178391,
#     "utilization": 0.14756337572838252,
#     "workload": 0.9876930968573748
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #15 ===============
# Observation:
# {
#     "n_instances": 1,
#     "pressure": 0.6921242516598243,
#     "queue_length_dominant": 0.9695757027223624,
#     "utilization": 0.8507939416882461,
#     "workload": 0.9039462746086918
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #16 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 2.4307648069194068,
#     "queue_length_dominant": 0.7800281817490254,
#     "utilization": 0.1014850775689119,
#     "workload": 0.46239532779732473
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #17 ===============
# Observation:
# {
#     "n_instances": 1,
#     "pressure": 0.9617232880317026,
#     "queue_length_dominant": 0.6565773171026555,
#     "utilization": 0.6157751614772976,
#     "workload": 0.13338692628073445
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #18 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 0.5099385181949085,
#     "queue_length_dominant": 0.2866055283987072,
#     "utilization": 0.8158949555798155,
#     "workload": 0.7295710336524966
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #19 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 1.9890764062876236,
#     "queue_length_dominant": 0.9435016892145303,
#     "utilization": 0.753658759634607,
#     "workload": 0.956210015598356
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #20 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 2.1318117677902504,
#     "queue_length_dominant": 0.5511602977587774,
#     "utilization": 0.162662958483896,
#     "workload": 0.014572506102256133
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #21 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 1.7381789464180524,
#     "queue_length_dominant": 0.9695138517471309,
#     "utilization": 0.13134931863797306,
#     "workload": 0.949926473075671
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #22 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.8049553027842886,
#     "queue_length_dominant": 0.16196482529345504,
#     "utilization": 0.22205522991709314,
#     "workload": 0.3493372756361274
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #23 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 2.423334742855372,
#     "queue_length_dominant": 0.9905761462800436,
#     "utilization": 0.9712931253954595,
#     "workload": 0.4277642219150868
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #24 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 0.7472500804131318,
#     "queue_length_dominant": 0.6794795308661524,
#     "utilization": 0.7291431085179354,
#     "workload": 0.8745468348717801
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #25 ===============
# Observation:
# {
#     "n_instances": 3,
#     "pressure": 2.355359513904888,
#     "queue_length_dominant": 0.1812690375515642,
#     "utilization": 0.2362699055824904,
#     "workload": 0.7774975285952964
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #26 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.4051345826726338,
#     "queue_length_dominant": 0.2653410328297087,
#     "utilization": 0.312165912798513,
#     "workload": 0.842676114274387
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #27 ===============
# Observation:
# {
#     "n_instances": 3,
#     "pressure": 0.4663361957916562,
#     "queue_length_dominant": 0.7473044907904635,
#     "utilization": 0.08663804541433895,
#     "workload": 0.46613113334477296
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #28 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.9323487569436695,
#     "queue_length_dominant": 0.5581767050706238,
#     "utilization": 0.6189307226087446,
#     "workload": 0.3403952314832345
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #29 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 1.3243127947007014,
#     "queue_length_dominant": 0.422260522536565,
#     "utilization": 0.4740649919884753,
#     "workload": 0.35323078504541106
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #30 ===============
# Observation:
# {
#     "n_instances": 3,
#     "pressure": 0.8755350269546354,
#     "queue_length_dominant": 0.5558070719206493,
#     "utilization": 0.046084197399077986,
#     "workload": 0.8147353925289547
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #31 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 1.0082715910404174,
#     "queue_length_dominant": 0.7715406602192592,
#     "utilization": 0.30051092523105927,
#     "workload": 0.009760755318492964
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #32 ===============
# Observation:
# {
#     "n_instances": 1,
#     "pressure": 0.6003111742458431,
#     "queue_length_dominant": 0.8624056302646878,
#     "utilization": 0.2991732016680031,
#     "workload": 0.7174096543853824
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #33 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 2.1384327493224458,
#     "queue_length_dominant": 0.39619764677759817,
#     "utilization": 0.5570807911279744,
#     "workload": 0.028558857097614743
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #34 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.1992706440794978,
#     "queue_length_dominant": 0.9626969629197282,
#     "utilization": 0.4051012860945832,
#     "workload": 0.7497005298459593
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #35 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 0.7234356243979282,
#     "queue_length_dominant": 0.7297095714370188,
#     "utilization": 0.9559652827669749,
#     "workload": 0.9953741995013192
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #36 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 1.4690756225135198,
#     "queue_length_dominant": 0.26195415673565414,
#     "utilization": 0.2340676254556292,
#     "workload": 0.9645438216061785
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #37 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 2.07223353168763,
#     "queue_length_dominant": 0.6155878930077326,
#     "utilization": 0.013798715235670223,
#     "workload": 0.525444680826066
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #38 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.1074747889515526,
#     "queue_length_dominant": 0.9561764624493916,
#     "utilization": 0.8754222340388009,
#     "workload": 0.4370465196461233
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #39 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 2.112302109896736,
#     "queue_length_dominant": 0.613157023356627,
#     "utilization": 0.6928317245554444,
#     "workload": 0.9977444034324872
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #40 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 0.16993413070349056,
#     "queue_length_dominant": 0.8682447008567075,
#     "utilization": 0.5733942872577502,
#     "workload": 0.2582914923769368
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #41 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.1790704947795299,
#     "queue_length_dominant": 0.25878921418636247,
#     "utilization": 0.9836445381152443,
#     "workload": 0.28923110945609987
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #42 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 2.057113279865169,
#     "queue_length_dominant": 0.782657283135053,
#     "utilization": 0.45260815384541,
#     "workload": 0.32120508604365416
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #43 ===============
# Observation:
# {
#     "n_instances": 1,
#     "pressure": 0.2584962739367298,
#     "queue_length_dominant": 0.17842945681283479,
#     "utilization": 0.8820783891317844,
#     "workload": 0.6581502378919033
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #44 ===============
# Observation:
# {
#     "n_instances": 1,
#     "pressure": 2.2019171138767115,
#     "queue_length_dominant": 0.5652048024665539,
#     "utilization": 0.7209012569606187,
#     "workload": 0.6098869017592947
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #45 ===============
# Observation:
# {
#     "n_instances": 3,
#     "pressure": 1.0323966118187526,
#     "queue_length_dominant": 0.9687421616808641,
#     "utilization": 0.7997748445145959,
#     "workload": 0.15488795353690077
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #46 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 0.8628301888616206,
#     "queue_length_dominant": 0.589544221818566,
#     "utilization": 0.707050571967068,
#     "workload": 0.28783965328980265
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #47 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 1.0401162640904844,
#     "queue_length_dominant": 0.2068441377633815,
#     "utilization": 0.03045413998522173,
#     "workload": 0.848154762567693
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #48 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 1.3095937253097345,
#     "queue_length_dominant": 0.7157099011596483,
#     "utilization": 0.7105659213067166,
#     "workload": 0.4045277239328756
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #49 ===============
# Observation:
# {
#     "n_instances": 1,
#     "pressure": 0.4279394055455812,
#     "queue_length_dominant": 0.6609735442510762,
#     "utilization": 0.02329850981273285,
#     "workload": 0.8127987780738187
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #50 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 0.8548936806509864,
#     "queue_length_dominant": 0.8811277892966041,
#     "utilization": 0.24121772280335874,
#     "workload": 0.29446294929837
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #51 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 0.7407588785570588,
#     "queue_length_dominant": 0.8179739450880493,
#     "utilization": 0.9376746535175859,
#     "workload": 0.6937550452739976
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #52 ===============
# Observation:
# {
#     "n_instances": 3,
#     "pressure": 2.23821669829748,
#     "queue_length_dominant": 0.546719789771541,
#     "utilization": 0.7711773919567164,
#     "workload": 0.8715737841104436
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #53 ===============
# Observation:
# {
#     "n_instances": 1,
#     "pressure": 0.6335911079198044,
#     "queue_length_dominant": 0.33465485457868605,
#     "utilization": 0.9624736509339715,
#     "workload": 0.9818403777476267
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #54 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 1.9985472886101652,
#     "queue_length_dominant": 0.5904217083799093,
#     "utilization": 0.4253966065765341,
#     "workload": 0.054549098502251425
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #55 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 1.9119327578581968,
#     "queue_length_dominant": 0.25418713881119476,
#     "utilization": 0.16177903127418913,
#     "workload": 0.2664797668183423
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #56 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 0.7754356765001943,
#     "queue_length_dominant": 0.595748034372341,
#     "utilization": 0.7167444836814353,
#     "workload": 0.3777591104437268
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #57 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 2.0020337501037715,
#     "queue_length_dominant": 0.6905094471260327,
#     "utilization": 0.8781072444818735,
#     "workload": 0.8027133808709424
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #58 ===============
# Observation:
# {
#     "n_instances": 1,
#     "pressure": 2.2805095426056163,
#     "queue_length_dominant": 0.6772592166672654,
#     "utilization": 0.8453948130357509,
#     "workload": 0.8864424200392081
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #59 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.140816325089233,
#     "queue_length_dominant": 0.6095126350485324,
#     "utilization": 0.025816297260685128,
#     "workload": 0.014271234501745056
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #60 ===============
# Observation:
# {
#     "n_instances": 3,
#     "pressure": 0.7497388150118366,
#     "queue_length_dominant": 0.3559750883021938,
#     "utilization": 0.5792952004947357,
#     "workload": 0.5691445356580848
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #61 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.3893418113456117,
#     "queue_length_dominant": 0.375223368952772,
#     "utilization": 0.40018703750330353,
#     "workload": 0.18202939790556327
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #62 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 1.329893434554718,
#     "queue_length_dominant": 0.6919301518865331,
#     "utilization": 0.1461147045751705,
#     "workload": 0.23301299590556146
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #63 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.1736897274564844,
#     "queue_length_dominant": 0.9763148962089474,
#     "utilization": 0.9666188120596892,
#     "workload": 0.8970716893160969
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #64 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 2.131757520651012,
#     "queue_length_dominant": 0.6208036699662646,
#     "utilization": 0.5937900739103463,
#     "workload": 0.10749995595494033
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #65 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 0.6385628553331372,
#     "queue_length_dominant": 0.41016059255195425,
#     "utilization": 0.4553438119812814,
#     "workload": 0.1576200230461967
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #66 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 0.5680909051597626,
#     "queue_length_dominant": 0.1308024397582186,
#     "utilization": 0.25301326466640595,
#     "workload": 0.5141347426354513
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #67 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 0.9195150557502456,
#     "queue_length_dominant": 0.5905130139609606,
#     "utilization": 0.1530812839304525,
#     "workload": 0.07728572598477368
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #68 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 0.6461103398487462,
#     "queue_length_dominant": 0.751129240407002,
#     "utilization": 0.8473669773223702,
#     "workload": 0.42517880307643163
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #69 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 2.4551480626877,
#     "queue_length_dominant": 0.8696652484514641,
#     "utilization": 0.8116758540878287,
#     "workload": 0.5455555408557771
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #70 ===============
# Observation:
# {
#     "n_instances": 1,
#     "pressure": 2.1528471604760195,
#     "queue_length_dominant": 0.46927339871386886,
#     "utilization": 0.7446094499374584,
#     "workload": 0.5576821063831904
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #71 ===============
# Observation:
# {
#     "n_instances": 3,
#     "pressure": 2.2607327239199324,
#     "queue_length_dominant": 0.845569102725666,
#     "utilization": 0.25783314554593373,
#     "workload": 0.9144662875441388
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #72 ===============
# Observation:
# {
#     "n_instances": 3,
#     "pressure": 2.2950264095055433,
#     "queue_length_dominant": 0.4657591585798615,
#     "utilization": 0.1504285361561335,
#     "workload": 0.7817107752120264
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #73 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 2.3146848105547093,
#     "queue_length_dominant": 0.5374189477630702,
#     "utilization": 0.15430569367846725,
#     "workload": 0.15447326364179792
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #74 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 1.5932241840926231,
#     "queue_length_dominant": 0.8853701170298963,
#     "utilization": 0.6371486117582333,
#     "workload": 0.11585207285142318
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #75 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.7344568422839906,
#     "queue_length_dominant": 0.866696092759152,
#     "utilization": 0.826828888875269,
#     "workload": 0.644238293578464
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #76 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 1.747665644835462,
#     "queue_length_dominant": 0.9356514958349563,
#     "utilization": 0.9902437039597559,
#     "workload": 0.1390254544661973
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #77 ===============
# Observation:
# {
#     "n_instances": 1,
#     "pressure": 0.7655269225413824,
#     "queue_length_dominant": 0.48433988812899853,
#     "utilization": 0.11910848443932043,
#     "workload": 0.9844365839665078
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #78 ===============
# Observation:
# {
#     "n_instances": 1,
#     "pressure": 0.7311953812474593,
#     "queue_length_dominant": 0.7760328907297955,
#     "utilization": 0.9742891679411206,
#     "workload": 0.6093291600818427
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #79 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.8432090356465283,
#     "queue_length_dominant": 0.1382213532603287,
#     "utilization": 0.26823887934396184,
#     "workload": 0.831535006678356
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #80 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 0.23891473482764924,
#     "queue_length_dominant": 0.6225309687573101,
#     "utilization": 0.4256526544886706,
#     "workload": 0.41230167203359347
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #81 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 0.8357118885389614,
#     "queue_length_dominant": 0.571863755090134,
#     "utilization": 0.390759659211934,
#     "workload": 0.05485717054513217
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #82 ===============
# Observation:
# {
#     "n_instances": 1,
#     "pressure": 1.6248543231728927,
#     "queue_length_dominant": 0.17361830747657528,
#     "utilization": 0.485635393200625,
#     "workload": 0.1886256134710439
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #83 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 1.701391747240757,
#     "queue_length_dominant": 0.4535515680234189,
#     "utilization": 0.27647635863469655,
#     "workload": 0.07313364812426904
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #84 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 0.43939596157091754,
#     "queue_length_dominant": 0.7384971559575438,
#     "utilization": 0.3571821363934594,
#     "workload": 0.03991897015262169
# }
# Response:
# {
#     "action": 1
# }
#
# =============== Observation #85 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 0.7184318218493468,
#     "queue_length_dominant": 0.7794100387772246,
#     "utilization": 0.3754742298713709,
#     "workload": 0.7649592258700891
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #86 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 0.814513610947876,
#     "queue_length_dominant": 0.20938792128228206,
#     "utilization": 0.7859003633346845,
#     "workload": 0.9525604109217408
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #87 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 1.8342404860372803,
#     "queue_length_dominant": 0.925313476574303,
#     "utilization": 0.7331327790918991,
#     "workload": 0.7868795406846443
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #88 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 1.803368198597913,
#     "queue_length_dominant": 0.8242276828105067,
#     "utilization": 0.4519122464131172,
#     "workload": 0.4350479717021092
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #89 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 0.3532125514767812,
#     "queue_length_dominant": 0.9316453907536087,
#     "utilization": 0.2724773831431333,
#     "workload": 0.9839554564787374
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #90 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 1.315335781175227,
#     "queue_length_dominant": 0.63279500028485,
#     "utilization": 0.2556451244635589,
#     "workload": 0.9791094762003164
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #91 ===============
# Observation:
# {
#     "n_instances": 5,
#     "pressure": 2.3106379912106103,
#     "queue_length_dominant": 0.30261593006913623,
#     "utilization": 0.7010170410004687,
#     "workload": 0.3133800914276025
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #92 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 2.2712481133432094,
#     "queue_length_dominant": 0.4264410138476272,
#     "utilization": 0.4666309963239824,
#     "workload": 0.2795447200921072
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #93 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 1.5962556927034106,
#     "queue_length_dominant": 0.7815208020337111,
#     "utilization": 0.13838382554033368,
#     "workload": 0.3120224908957361
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #94 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 1.8878417354843042,
#     "queue_length_dominant": 0.13506049597448266,
#     "utilization": 0.46528646307928956,
#     "workload": 0.8833358978655705
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #95 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 2.2287115837891123,
#     "queue_length_dominant": 0.8567182973329801,
#     "utilization": 0.35724614120556186,
#     "workload": 0.5594463736502775
# }
# Response:
# {
#     "action": 5
# }
#
# =============== Observation #96 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 0.324490480971369,
#     "queue_length_dominant": 0.7063412846948577,
#     "utilization": 0.7225182624672748,
#     "workload": 0.31866371900379653
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #97 ===============
# Observation:
# {
#     "n_instances": 4,
#     "pressure": 0.5784569233964435,
#     "queue_length_dominant": 0.22248208431046634,
#     "utilization": 0.05344798559840702,
#     "workload": 0.21350689146857793
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #98 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 1.523866203177892,
#     "queue_length_dominant": 0.3179715973885111,
#     "utilization": 0.8570818709671587,
#     "workload": 0.014022169318471889
# }
# Response:
# {
#     "action": 3
# }
#
# =============== Observation #99 ===============
# Observation:
# {
#     "n_instances": 2,
#     "pressure": 0.4085620045012843,
#     "queue_length_dominant": 0.55329292691938,
#     "utilization": 0.8168999643056295,
#     "workload": 0.6031427573296398
# }
# Response:
# {
#     "action": 4
# }
#
# =============== Observation #100 ===============
# Observation:
# {
#     "n_instances": 6,
#     "pressure": 2.188196513387428,
#     "queue_length_dominant": 0.739657753411595,
#     "utilization": 0.5870290894504283,
#     "workload": 0.9985505389724575
# }
# Response:
# {
#     "action": 3
# }

# %%
observation = random_obs()
response = requests.post('http://127.0.0.1:5100/action', json={'observation': observation})
response.json()
# Out:
# {'action': 1}

# %%
response = requests.post('http://localhost:5000/shutdown')
response
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connection.py:445, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     444     self.putheader(header, value)
# --> 445 self.endheaders()
#     447 # If we're given a body we start sending that in chunks.
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1035, in HTTPConnection.send(self, data)
#    1034 if self.auto_open:
# -> 1035     self.connect()
#    1036 else:
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connection.py:276, in HTTPConnection.connect(self)
#     275 def connect(self) -> None:
# --> 276     self.sock = self._new_conn()
#     277     if self._tunnel_host:
#     278         # If we're tunneling it means we're connected to our proxy.
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connection.py:213, in HTTPConnection._new_conn(self)
#     212 except OSError as e:
# --> 213     raise NewConnectionError(
#     214         self, f"Failed to establish a new connection: {e}"
#     215     ) from e
#     217 sys.audit("http.client.connect", self, self.host, self.port)
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x10bd0b570>: Failed to establish a new connection: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=5000): Max retries exceeded with url: /shutdown (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10bd0b570>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 response = requests.post('http://localhost:5000/shutdown')
#       2 response
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=5000): Max retries exceeded with url: /shutdown (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10bd0b570>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
response.json()

# %%
for i in range(10):
    observation = random_obs()
    response = requests.post('http://localhost:5000/action', json={'observation': observation})
    action = response.json()['action']
    reward = np.random.uniform(0, 1)
    next_observation = random_obs()
    obs = [v for v in observation.values()]
    next_obs = [v for v in next_observation.values()]
    learn_dict['observations'].append(obs)
    learn_dict['actions'].append(action)
    learn_dict['rewards'].append(reward)
    learn_dict['next_observations'].append(next_obs)
    learn_dict['timesteps'].append(i)

print('learn dict dimensions:', len(learn_dict['observations']), len(learn_dict['actions']), len(learn_dict['rewards']), len(learn_dict['next_observations']), len(learn_dict['timesteps']))
print('obs dimensions:', len(learn_dict['observations'][0]), len(learn_dict['next_observations'][0]))

response = requests.post('http://localhost:5000/learn', json=learn_dict)
print(response.json())
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connection.py:198, in HTTPConnection._new_conn(self)
#     197 try:
# --> 198     sock = connection.create_connection(
#     199         (self._dns_host, self.port),
#     200         self.timeout,
#     201         source_address=self.source_address,
#     202         socket_options=self.socket_options,
#     203     )
#     204 except socket.gaierror as e:
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84 try:
# ---> 85     raise err
#      86 finally:
#      87     # Break explicitly a reference cycle
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/util/connection.py:73, in create_connection(address, timeout, source_address, socket_options)
#      72     sock.bind(source_address)
# ---> 73 sock.connect(sa)
#      74 # Break explicitly a reference cycle
#
# ConnectionRefusedError: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:787, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 # Make the request on the HTTPConnection object
# --> 787 response = self._make_request(
#     788     conn,
#     789     method,
#     790     url,
#     791     timeout=timeout_obj,
#     792     body=body,
#     793     headers=headers,
#     794     chunked=chunked,
#     795     retries=retries,
#     796     response_conn=response_conn,
#     797     preload_content=preload_content,
#     798     decode_content=decode_content,
#     799     **response_kw,
#     800 )
#     802 # Everything went great!
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:493, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     492 try:
# --> 493     conn.request(
#     494         method,
#     495         url,
#     496         body=body,
#     497         headers=headers,
#     498         chunked=chunked,
#     499         preload_content=preload_content,
#     500         decode_content=decode_content,
#     501         enforce_content_length=enforce_content_length,
#     502     )
#     504 # We are swallowing BrokenPipeError (errno.EPIPE) since the server is
#     505 # legitimately able to close the connection after sending a valid response.
#     506 # With this behaviour, the received response is still readable.
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connection.py:445, in HTTPConnection.request(self, method, url, body, headers, chunked, preload_content, decode_content, enforce_content_length)
#     444     self.putheader(header, value)
# --> 445 self.endheaders()
#     447 # If we're given a body we start sending that in chunks.
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1331, in HTTPConnection.endheaders(self, message_body, encode_chunked)
#    1330     raise CannotSendHeader()
# -> 1331 self._send_output(message_body, encode_chunked=encode_chunked)
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1091, in HTTPConnection._send_output(self, message_body, encode_chunked)
#    1090 del self._buffer[:]
# -> 1091 self.send(msg)
#    1093 if message_body is not None:
#    1094
#    1095     # create a consistent interface to message_body
#
# File /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/http/client.py:1035, in HTTPConnection.send(self, data)
#    1034 if self.auto_open:
# -> 1035     self.connect()
#    1036 else:
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connection.py:276, in HTTPConnection.connect(self)
#     275 def connect(self) -> None:
# --> 276     self.sock = self._new_conn()
#     277     if self._tunnel_host:
#     278         # If we're tunneling it means we're connected to our proxy.
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connection.py:213, in HTTPConnection._new_conn(self)
#     212 except OSError as e:
# --> 213     raise NewConnectionError(
#     214         self, f"Failed to establish a new connection: {e}"
#     215     ) from e
#     217 sys.audit("http.client.connect", self, self.host, self.port)
#
# NewConnectionError: <urllib3.connection.HTTPConnection object at 0x10ca29150>: Failed to establish a new connection: [Errno 61] Connection refused
#
# The above exception was the direct cause of the following exception:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/connectionpool.py:841, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     839     new_e = ProtocolError("Connection aborted.", new_e)
# --> 841 retries = retries.increment(
#     842     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     843 )
#     844 retries.sleep()
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/urllib3/util/retry.py:519, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     518     reason = error or ResponseError(cause)
# --> 519     raise MaxRetryError(_pool, url, reason) from reason  # type: ignore[arg-type]
#     521 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPConnectionPool(host='localhost', port=5000): Max retries exceeded with url: /action (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10ca29150>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[8], line 3
#       1 for i in range(10):
#       2     observation = random_obs()
# ----> 3     response = requests.post('http://localhost:5000/action', json={'observation': observation})
#       4     action = response.json()['action']
#       5     reward = np.random.uniform(0, 1)
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/requests/api.py:115, in post(url, data, json, **kwargs)
#     103 def post(url, data=None, json=None, **kwargs):
#     104     r"""Sends a POST request.
#     105
#     106     :param url: URL for the new :class:`Request` object.
#    (...)    112     :rtype: requests.Response
#     113     """
# --> 115     return request("post", url, data=data, json=json, **kwargs)
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/requests/api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/Desktop/MASTER/1 year/Semester 1/SOFTWARE ENGINEERING 2/RESEARCH PROJECT/adaptative-resource-management-ai/JMeter/venv/lib/python3.13/site-packages/requests/adapters.py:700, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     696     if isinstance(e.reason, _SSLError):
#     697         # This branch is for urllib3 v1.22 and later.
#     698         raise SSLError(e, request=request)
# --> 700     raise ConnectionError(e, request=request)
#     702 except ClosedPoolError as e:
#     703     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPConnectionPool(host='localhost', port=5000): Max retries exceeded with url: /action (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x10ca29150>: Failed to establish a new connection: [Errno 61] Connection refused'))

# %%
len(learn_dict["observations"])
